# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/ahearn/OneDrive - MJ Insurance/Desktop/Python/Practice Data Sets/insurance.csv')

# %%
#Pycart
from pycaret.regression import *

# %%
#rs is model name in Tutorial - https://towardsdatascience.com/build-and-deploy-machine-learning-web-app-using-pycaret-and-streamlit-28883a569104
r2 = setup(data, target = 'charges', session_id = 123,
          normalize = True,
          polynomial_features = True, trigonometry_features = True,
          feature_interaction=True,
          bin_numeric_features= ['age', 'bmi'])
# Out:
# <style  type="text/css" >
#     #T_e1ea444a_9234_11eb_8db7_6c6a77afba12row27_col1 {
#             background-color:  lightgreen;
#         }    #T_e1ea444a_9234_11eb_8db7_6c6a77afba12row37_col1 {
#             background-color:  lightgreen;
#         }    #T_e1ea444a_9234_11eb_8db7_6c6a77afba12row44_col1 {
#             background-color:  lightgreen;
#         }    #T_e1ea444a_9234_11eb_8db7_6c6a77afba12row46_col1 {
#             background-color:  lightgreen;
#         }    #T_e1ea444a_9234_11eb_8db7_6c6a77afba12row51_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_e1ea444a_9234_11eb_8db7_6c6a77afba12" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1ea444a_9234_11eb_8db7_6c6a77afba12level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
#Check top performing models on data
top3 = compare_models(exclude = ['ransac'], n_select = 3)
# Out:
# <style  type="text/css" >
#     #T_2fee0713_9235_11eb_b3dd_6c6a77afba12 th {
#           text-align: left;
#     }    #T_2fee0713_9235_11eb_b3dd_6c6a77afba12row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_2fee0713_9235_11eb_b3dd_6c6a77afba12row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_2fee0713_9235_11eb_b3dd_6c6a77afba12row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_2fee0713_9235_11eb_b3dd_6c6a77afba12row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_2fee0713_9235_11eb_b3dd_6c6a77afba12row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_2fee0713_9235_11eb_b3dd_6c6a77afba12row0_col5 {
# ...

# %%
gbr = create_model('gbr', fold = 10, round = 3)
# Out:
# <style  type="text/css" >
#     #T_5bf9fcf4_9235_11eb_a106_6c6a77afba12row10_col0 {
#             background:  yellow;
#         }    #T_5bf9fcf4_9235_11eb_a106_6c6a77afba12row10_col1 {
#             background:  yellow;
#         }    #T_5bf9fcf4_9235_11eb_a106_6c6a77afba12row10_col2 {
#             background:  yellow;
#         }    #T_5bf9fcf4_9235_11eb_a106_6c6a77afba12row10_col3 {
#             background:  yellow;
#         }    #T_5bf9fcf4_9235_11eb_a106_6c6a77afba12row10_col4 {
#             background:  yellow;
#         }    #T_5bf9fcf4_9235_11eb_a106_6c6a77afba12row10_col5 {
#             background:  yellow;
# ...

# %%
#save model
save_model(gbr, model_name = 'deployment_20210331')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='charges',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy...
#                                             learning_rate=0.1, loss='ls',
#                                             max_depth=3, max_features=None,
#                                             max_leaf_nodes=None,
# ...

# %%
deployment_20210331 = load_model('deployment_20210331')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
deployment_20210331
# Out:
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[], target='charges',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy...
#                                            learning_rate=0.1, loss='ls',
#                                            max_depth=3, max_features=None,
#                                            max_leaf_nodes=None,
#                                            min_impurity_decrease=0.0,
# ...
